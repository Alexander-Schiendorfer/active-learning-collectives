# %%
# plots for abstracted penalty functions

import numpy as np

path_to_csv = "Penalty5.csv"
data = np.genfromtxt(path_to_csv, dtype=float, delimiter=';')
#times = data[:,0].astype(int)
power5 = data[:,0]
penalties5 = data[:,1]

path_to_csv = "Penalty10.csv"
data = np.genfromtxt(path_to_csv, dtype=float, delimiter=';')
#times = data[:,0].astype(int)
power10 = data[:,0]
penalties10 = data[:,1]

path_to_csv = "Penalty20.csv"
data = np.genfromtxt(path_to_csv, dtype=float, delimiter=';')
#times = data[:,0].astype(int)
power20 = data[:,0]
penalties20 = data[:,1]

# %%
import pylab
import numpy as np
from pylab import arange,pi,sin,cos,sqrt
fig_width_pt = 400  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inch
golden_mean = (sqrt(5)-1.0)/2.0         # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_width*golden_mean      # height in inches
fig_size =  [fig_width,fig_height]

#plt.setp(lines, color=isseorange, linewidth=2.0)
params = {'backend': 'ps',
          'axes.labelsize': 20,
          'text.fontsize': 18,
          'legend.fontsize': 14,
          'xtick.labelsize': 14,
          'ytick.labelsize': 14,
          'text.usetex': True,
          'figure.figsize': fig_size}
pylab.rcParams.update(params)
# Generate data
# Plot data
pylab.figure(1)
pylab.rcParams.update(params)
pylab.clf()
pylab.axes([0.125,0.2,0.95-0.125,0.95-0.2])

plt.plot(power5, penalties5, color="red", label="5 sampling points")
plt.plot(power10, penalties10, color="blue", label="10 sampling points")
plt.plot(power20, penalties20, color="green", label="20 sampling points")
pylab.xlabel('$\mathcal{P}$')
pylab.ylabel('$P$')
#pylab.legend()
legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pylab.savefig('powerToPenalty.pdf', bbox_inches='tight', pad_inches=0.1)
